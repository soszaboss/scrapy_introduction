# %%
import pandas as pd
import json

# %%
with open('../books.json', encoding='utf-8') as file:
    data = json.load(file)
df = pd.json_normalize(data)
df
# Out:
#                                                  title  price  \
# 0                         Libertarianism for Beginners  51.33
# 1                            Rip it Up and Start Again  35.02
# 2    Our Band Could Be Your Life: Scenes from the A...  57.25
# 3                                                 Olio  23.88
# 4    Scott Pilgrim's Precious Little Life (Scott Pi...  52.29
# ..                                                 ...    ...
# 995                                               Emma  32.93
# 996  Choosing Our Religion: The Spiritual Lives of ...  28.42
# 997                        Fighting Fate (Fighting #6)  39.24
# 998                   Forever Rockers (The Rocker #12)  28.80
# 999                                       Frankenstein  38.00
#
#                                            description               upc  \
# 0    Libertarianism isn't about winning elections; ...  a18a4f574854aced
# 1    Punk's raw power rejuvenated rock, but by the ...  a34ba96d4081e6a4
# 2    This is the never-before-told story of the mus...  deda3e61b9514b83
# 3    Part fact, part fiction, Tyehimba Jess's much ...  feb7cc7701ecf901
# 4    Scott Pilgrim's life is totally sweet. He's 23...  3b1c02bac2a429e6
# ..                                                 ...               ...
# 995  'I never have been in love; it is not my way, ...  2e69730561ed70ad
# 996  To the dismay of religious leaders, study afte...  a812f6969ddf3e39
# 997  ***BONUS CONTENT: The first two chapters of JB...  6390772a3094939d
# 998  My Happily Ever After was turning into a livin...  e564c3f1a93ccf2e
# 999  Mary Shelley began writing Frankenstein when s...  a492f49a3e2b6a71
#
#      avaibility
# 0            19
# 1            19
# 2            19
# 3            19
# 4            19
# ..          ...
# 995           1
# 996           1
# 997           1
# 998           1
# 999           1
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1000 non-null   object
#  1   price        1000 non-null   float64
#  2   description  1000 non-null   object
#  3   upc          1000 non-null   object
#  4   avaibility   1000 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
df['description'] = df['description'].apply(lambda x: str(x).strip())
df
# Out:
#                                                  title  price  \
# 0                         Libertarianism for Beginners  51.33
# 1                            Rip it Up and Start Again  35.02
# 2    Our Band Could Be Your Life: Scenes from the A...  57.25
# 3                                                 Olio  23.88
# 4    Scott Pilgrim's Precious Little Life (Scott Pi...  52.29
# ..                                                 ...    ...
# 995                                               Emma  32.93
# 996  Choosing Our Religion: The Spiritual Lives of ...  28.42
# 997                        Fighting Fate (Fighting #6)  39.24
# 998                   Forever Rockers (The Rocker #12)  28.80
# 999                                       Frankenstein  38.00
#
#                                            description               upc  \
# 0    Libertarianism isn't about winning elections; ...  a18a4f574854aced
# 1    Punk's raw power rejuvenated rock, but by the ...  a34ba96d4081e6a4
# 2    This is the never-before-told story of the mus...  deda3e61b9514b83
# 3    Part fact, part fiction, Tyehimba Jess's much ...  feb7cc7701ecf901
# 4    Scott Pilgrim's life is totally sweet. He's 23...  3b1c02bac2a429e6
# ..                                                 ...               ...
# 995  'I never have been in love; it is not my way, ...  2e69730561ed70ad
# 996  To the dismay of religious leaders, study afte...  a812f6969ddf3e39
# 997  ***BONUS CONTENT: The first two chapters of JB...  6390772a3094939d
# 998  My Happily Ever After was turning into a livin...  e564c3f1a93ccf2e
# 999  Mary Shelley began writing Frankenstein when s...  a492f49a3e2b6a71
#
#      avaibility
# 0            19
# 1            19
# 2            19
# 3            19
# 4            19
# ..          ...
# 995           1
# 996           1
# 997           1
# 998           1
# 999           1
#
# [1000 rows x 5 columns]
