# %%
import pandas as pd
import json

# %%
with open('books.json', encoding='utf-8') as file:
    data = json.load(file)
df = pd.json_normalize(data)
df
# Out:
#                                                  title  price  \
# 0    Our Band Could Be Your Life: Scenes from the A...  57.25
# 1                                                 Olio  23.88
# 2                                          Set Me Free  17.46
# 3                         Libertarianism for Beginners  51.33
# 4                            Rip it Up and Start Again  35.02
# ..                                                 ...    ...
# 995                        All the Light We Cannot See  29.87
# 996  The Mindfulness and Acceptance Workbook for An...  23.89
# 997  The Bridge to Consciousness: I'm Writing the B...  32.00
# 998  The Most Perfect Thing: Inside (and Outside) a...  42.96
# 999  The Murder That Never Was (Forensic Instincts #5)  54.11
#
#                                            description               upc  \
# 0    This is the never-before-told story of the mus...  deda3e61b9514b83
# 1    Part fact, part fiction, Tyehimba Jess's much ...  feb7cc7701ecf901
# 2    Aaron Ledbetter’s future had been planned out ...  ce6396b0f23f6ecc
# 3    Libertarianism isn't about winning elections; ...  a18a4f574854aced
# 4    Punk's raw power rejuvenated rock, but by the ...  a34ba96d4081e6a4
# ..                                                 ...               ...
# 995  WINNER OF THE PULITZER PRIZEFrom the highly ac...  39861fc1c0845d15
# 996  Is anxiety and fear a problem for you? Have yo...  31075275518532d7
# 997                                               None  efc3768127714ec3
# 998  Renowned ornithologist Tim Birkhead opens this...  aadee1c326d286e3
# 999  Given the opportunity, would you assume someon...  d01ac97e2b8947c2
#
#      avaibility
# 0            19
# 1            19
# 2            19
# 3            19
# 4            19
# ..          ...
# 995          14
# 996          16
# 997          15
# 998          16
# 999          16
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1000 non-null   object
#  1   price        1000 non-null   float64
#  2   description  1000 non-null   object
#  3   upc          1000 non-null   object
#  4   avaibility   1000 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
df['description'] = df['description'].apply(lambda x: str(x).strip())
df
# Out:
#                                                  title  price  \
# 0    Our Band Could Be Your Life: Scenes from the A...  57.25
# 1                                                 Olio  23.88
# 2                                          Set Me Free  17.46
# 3                         Libertarianism for Beginners  51.33
# 4                            Rip it Up and Start Again  35.02
# ..                                                 ...    ...
# 995                        All the Light We Cannot See  29.87
# 996  The Mindfulness and Acceptance Workbook for An...  23.89
# 997  The Bridge to Consciousness: I'm Writing the B...  32.00
# 998  The Most Perfect Thing: Inside (and Outside) a...  42.96
# 999  The Murder That Never Was (Forensic Instincts #5)  54.11
#
#                                            description               upc  \
# 0    This is the never-before-told story of the mus...  deda3e61b9514b83
# 1    Part fact, part fiction, Tyehimba Jess's much ...  feb7cc7701ecf901
# 2    Aaron Ledbetter’s future had been planned out ...  ce6396b0f23f6ecc
# 3    Libertarianism isn't about winning elections; ...  a18a4f574854aced
# 4    Punk's raw power rejuvenated rock, but by the ...  a34ba96d4081e6a4
# ..                                                 ...               ...
# 995  WINNER OF THE PULITZER PRIZEFrom the highly ac...  39861fc1c0845d15
# 996  Is anxiety and fear a problem for you? Have yo...  31075275518532d7
# 997                                               None  efc3768127714ec3
# 998  Renowned ornithologist Tim Birkhead opens this...  aadee1c326d286e3
# 999  Given the opportunity, would you assume someon...  d01ac97e2b8947c2
#
#      avaibility
# 0            19
# 1            19
# 2            19
# 3            19
# 4            19
# ..          ...
# 995          14
# 996          16
# 997          15
# 998          16
# 999          16
#
# [1000 rows x 5 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
