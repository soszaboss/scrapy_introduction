# %%
import pandas as pd

# %%
df = pd.read_csv("books.csv")
df
# Out:
#      avaibility                                        description  price  \
# 0            19  Aaron Ledbetter’s future had been planned out ...  17.46
# 1            19  Libertarianism isn't about winning elections; ...  51.33
# 2            19  “Wherever you go, whatever you do, just . . . ...  45.17
# 3            19  This is the never-before-told story of the mus...  57.25
# 4            19  This book is an important and complete collect...  20.66
# ..          ...                                                ...    ...
# 995           1  To the dismay of religious leaders, study afte...  28.42
# 996           1  Meet Bridget Jones—a 30-something Singleton wh...  29.82
# 997           1  ***BONUS CONTENT: The first two chapters of JB...  39.24
# 998           1  My Happily Ever After was turning into a livin...  28.80
# 999           1  Mary Shelley began writing Frankenstein when s...  38.00
#
#                                                  title               upc
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   avaibility   1000 non-null   int64
#  1   description  998 non-null    object
#  2   price        1000 non-null   float64
#  3   title        1000 non-null   object
#  4   upc          1000 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
df['description'] = df['description'].apply(lambda x: str(x).strip())
df
# Out:
#      avaibility                                        description  price  \
# 0            19  Aaron Ledbetter’s future had been planned out ...  17.46
# 1            19  Libertarianism isn't about winning elections; ...  51.33
# 2            19  “Wherever you go, whatever you do, just . . . ...  45.17
# 3            19  This is the never-before-told story of the mus...  57.25
# 4            19  This book is an important and complete collect...  20.66
# ..          ...                                                ...    ...
# 995           1  To the dismay of religious leaders, study afte...  28.42
# 996           1  Meet Bridget Jones—a 30-something Singleton wh...  29.82
# 997           1  ***BONUS CONTENT: The first two chapters of JB...  39.24
# 998           1  My Happily Ever After was turning into a livin...  28.80
# 999           1  Mary Shelley began writing Frankenstein when s...  38.00
#
#                                                  title               upc
# ...
